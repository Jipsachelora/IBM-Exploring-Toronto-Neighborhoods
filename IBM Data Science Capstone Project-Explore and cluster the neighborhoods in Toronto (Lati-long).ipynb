# %% [markdown]
# Importing all libraries needed for the complete project: IBM Data Science Capstone Project-Explore and cluster the neighborhoods in Toronto

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0        conda-forge
#     geopy:         1.17.0-py_0      conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:       2018.4.16-py36_0             --> 2018.4.16-py36_0 conda-forge
#     conda:         4.5.4-py36_0                 --> 4.5.11-py36_1000 conda-forge
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... failed
# Rolling back transaction: ...working... done
# ERROR conda.core.link:_execute(502): An error occurred while uninstalling package 'defaults::conda-4.5.4-py36_0'.
# PermissionError(13, 'Access is denied')
# Attempting to roll back.
#
#
# PermissionError(13, 'Access is denied')
# ...

# %% [markdown]
# Importing all libraries needed for scrapping the web

# %%
import pandas as pd
from io import StringIO

# %% [markdown]
# Getting the content of the URL ...making an HTTP Get request

# %%
import pandas as pd

tables_data=pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")

print(tables_data[0])
# Out:
#             0                 1  \
# 0    Postcode           Borough
# 1         M1A      Not assigned
# 2         M2A      Not assigned
# 3         M3A        North York
# 4         M4A        North York
# 5         M5A  Downtown Toronto
# 6         M5A  Downtown Toronto
# 7         M6A        North York
# 8         M6A        North York
# 9         M7A      Queen's Park
# 10        M8A      Not assigned
# 11        M9A         Etobicoke
# 12        M1B       Scarborough
# 13        M1B       Scarborough
# 14        M2B      Not assigned
# 15        M3B        North York
# 16        M4B         East York
# 17        M4B         East York
# 18        M5B  Downtown Toronto
# 19        M5B  Downtown Toronto
# 20        M6B        North York
# 21        M7B      Not assigned
# 22        M8B      Not assigned
# 23        M9B         Etobicoke
# 24        M9B         Etobicoke
# 25        M9B         Etobicoke
# 26        M9B         Etobicoke
# 27        M9B         Etobicoke
# ...

# %% [markdown]
# let's define the dataframe columns

# %%
neighborhoods_data=tables_data[0]

# %%
neighborhoods_data
# Out:
#             0                 1  \
# 0    Postcode           Borough
# 1         M1A      Not assigned
# 2         M2A      Not assigned
# 3         M3A        North York
# 4         M4A        North York
# 5         M5A  Downtown Toronto
# 6         M5A  Downtown Toronto
# 7         M6A        North York
# 8         M6A        North York
# 9         M7A      Queen's Park
# 10        M8A      Not assigned
# 11        M9A         Etobicoke
# 12        M1B       Scarborough
# 13        M1B       Scarborough
# 14        M2B      Not assigned
# 15        M3B        North York
# 16        M4B         East York
# 17        M4B         East York
# 18        M5B  Downtown Toronto
# 19        M5B  Downtown Toronto
# 20        M6B        North York
# 21        M7B      Not assigned
# 22        M8B      Not assigned
# 23        M9B         Etobicoke
# 24        M9B         Etobicoke
# 25        M9B         Etobicoke
# 26        M9B         Etobicoke
# 27        M9B         Etobicoke
# ...

# %%
column_names=['PostalCode', 'Borough', 'Neighborhood']

# %% [markdown]
# instatiate the dataframe

# %%
neighborhoods= pd.DataFrame(columns=column_names)

# %%
neighborhoods
neighborhoods_data
# Out:
#             0                 1  \
# 0    Postcode           Borough
# 1         M1A      Not assigned
# 2         M2A      Not assigned
# 3         M3A        North York
# 4         M4A        North York
# 5         M5A  Downtown Toronto
# 6         M5A  Downtown Toronto
# 7         M6A        North York
# 8         M6A        North York
# 9         M7A      Queen's Park
# 10        M8A      Not assigned
# 11        M9A         Etobicoke
# 12        M1B       Scarborough
# 13        M1B       Scarborough
# 14        M2B      Not assigned
# 15        M3B        North York
# 16        M4B         East York
# 17        M4B         East York
# 18        M5B  Downtown Toronto
# 19        M5B  Downtown Toronto
# 20        M6B        North York
# 21        M7B      Not assigned
# 22        M8B      Not assigned
# 23        M9B         Etobicoke
# 24        M9B         Etobicoke
# 25        M9B         Etobicoke
# 26        M9B         Etobicoke
# 27        M9B         Etobicoke
# ...

# %% [markdown]
# Lets fill the dataframe

# %%
neighborhoods_data.rename(columns=neighborhoods_data.iloc[0])
# Out:
#      Postcode           Borough  \
# 0    Postcode           Borough
# 1         M1A      Not assigned
# 2         M2A      Not assigned
# 3         M3A        North York
# 4         M4A        North York
# 5         M5A  Downtown Toronto
# 6         M5A  Downtown Toronto
# 7         M6A        North York
# 8         M6A        North York
# 9         M7A      Queen's Park
# 10        M8A      Not assigned
# 11        M9A         Etobicoke
# 12        M1B       Scarborough
# 13        M1B       Scarborough
# 14        M2B      Not assigned
# 15        M3B        North York
# 16        M4B         East York
# 17        M4B         East York
# 18        M5B  Downtown Toronto
# 19        M5B  Downtown Toronto
# 20        M6B        North York
# 21        M7B      Not assigned
# 22        M8B      Not assigned
# 23        M9B         Etobicoke
# 24        M9B         Etobicoke
# 25        M9B         Etobicoke
# 26        M9B         Etobicoke
# 27        M9B         Etobicoke
# ...

# %%
neighborhoods_data1 = neighborhoods_data.iloc[1:]

# %%
neighborhoods_data2=neighborhoods_data1.rename(columns=neighborhoods_data.iloc[0])

# %%
neighborhoods_data2
# Out:
#     Postcode           Borough  \
# 1        M1A      Not assigned
# 2        M2A      Not assigned
# 3        M3A        North York
# 4        M4A        North York
# 5        M5A  Downtown Toronto
# 6        M5A  Downtown Toronto
# 7        M6A        North York
# 8        M6A        North York
# 9        M7A      Queen's Park
# 10       M8A      Not assigned
# 11       M9A         Etobicoke
# 12       M1B       Scarborough
# 13       M1B       Scarborough
# 14       M2B      Not assigned
# 15       M3B        North York
# 16       M4B         East York
# 17       M4B         East York
# 18       M5B  Downtown Toronto
# 19       M5B  Downtown Toronto
# 20       M6B        North York
# 21       M7B      Not assigned
# 22       M8B      Not assigned
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M9B         Etobicoke
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# ...

# %%
neighborhoods_data2.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 1      M1A      Not assigned      Not assigned
# 2      M2A      Not assigned      Not assigned
# 3      M3A        North York         Parkwoods
# 4      M4A        North York  Victoria Village
# 5      M5A  Downtown Toronto      Harbourfront

# %%
import pandas as pd
df=pd.read_csv('Geospatial_Coordinates.csv')

# %%
dftotal=pd.concat([df,neighborhoods_data2], sort=True)
dftotal.head()
# Out:
#   Borough   Latitude  Longitude Neighbourhood Postal Code Postcode
# 0     NaN  43.806686 -79.194353           NaN         M1B      NaN
# 1     NaN  43.784535 -79.160497           NaN         M1C      NaN
# 2     NaN  43.763573 -79.188711           NaN         M1E      NaN
# 3     NaN  43.770992 -79.216917           NaN         M1G      NaN
# 4     NaN  43.773136 -79.239476           NaN         M1H      NaN

# %%
dftotal
# Out:
#               Borough   Latitude  Longitude  \
# 1        Not assigned        NaN        NaN
# 2        Not assigned        NaN        NaN
# 3          North York        NaN        NaN
# 4          North York        NaN        NaN
# 5    Downtown Toronto        NaN        NaN
# 6    Downtown Toronto        NaN        NaN
# 7          North York        NaN        NaN
# 8          North York        NaN        NaN
# 9        Queen's Park        NaN        NaN
# 10       Not assigned        NaN        NaN
# 11          Etobicoke        NaN        NaN
# 12        Scarborough        NaN        NaN
# 13        Scarborough        NaN        NaN
# 14       Not assigned        NaN        NaN
# 15         North York        NaN        NaN
# 16          East York        NaN        NaN
# 17          East York        NaN        NaN
# 18   Downtown Toronto        NaN        NaN
# 19   Downtown Toronto        NaN        NaN
# 20         North York        NaN        NaN
# ...
